# %%
# LangChain
from langchain.document_loaders import UnstructuredFileLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Pinecone

# NLTK
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from langchain.text_splitter import NLTKTextSplitter

import openai

# Pinecone
import pinecone

import os
import streamlit as st
import requests
from dotenv import load_dotenv
import json
import pandas as pd
import numpy as np

load_dotenv()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/trevormcgirr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# PINECONE_API_KEY = os.environ.get("PINECONE_API_KEY")
# PINECONE_INDEX_NAME = os.environ.get("PINECONE_INDEX_NAME")
PINECONE_API_KEY = ""
PINECONE_INDEX_NAME = "gcp-starter"

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
openai.api_key = OPENAI_API_KEY

pinecone.init(       
 api_key=PINECONE_API_KEY,
 environment=PINECONE_INDEX_NAME 
)      
index = pinecone.Index('chatbot')

# OpenAI Embeddings
embeddings = OpenAIEmbeddings()

# %%
# https://www.kaggle.com/code/sanjay11100/squad-stanford-q-a-json-to-pandas-dataframe
def squad_json_to_dataframe_train(input_file_path, record_path = ['data','paragraphs','qas','answers'],
                           verbose = 1):
    """
    input_file_path: path to the squad json file.
    record_path: path to deepest level in json file default value is
    ['data','paragraphs','qas','answers']
    verbose: 0 to suppress it default is 1
    """
    if verbose:
        print("Reading the json file")    
    file = json.loads(open(input_file_path).read())
    if verbose:
        print("processing...")
    # parsing different level's in the json file
    js = pd.io.json.json_normalize(file , record_path )
    m = pd.io.json.json_normalize(file, record_path[:-1] )
    r = pd.io.json.json_normalize(file,record_path[:-2])
    
    #combining it into single dataframe
    idx = np.repeat(r['context'].values, r.qas.str.len())
    ndx  = np.repeat(m['id'].values,m['answers'].str.len())
    m['context'] = idx
    js['q_idx'] = ndx
    main = pd.concat([ m[['id','question','context']].set_index('id'),js.set_index('q_idx')],1,sort=False).reset_index()
    main['c_id'] = main['context'].factorize()[0]
    if verbose:
        print("shape of the dataframe is {}".format(main.shape))
        print("Done")
    return main
  
def squad_json_to_dataframe_dev(input_file_path, record_path = ['data','paragraphs','qas','answers'],
                           verbose = 1):
    """
    input_file_path: path to the squad json file.
    record_path: path to deepest level in json file default value is
    ['data','paragraphs','qas','answers']
    verbose: 0 to suppress it default is 1
    """
    if verbose:
        print("Reading the json file")    
    file = json.loads(open(input_file_path).read())
    if verbose:
        print("processing...")
    # parsing different level's in the json file
    js = pd.io.json.json_normalize(file , record_path )
    m = pd.io.json.json_normalize(file, record_path[:-1] )
    r = pd.io.json.json_normalize(file,record_path[:-2])
    
    #combining it into single dataframe
    idx = np.repeat(r['context'].values, r.qas.str.len())
#     ndx  = np.repeat(m['id'].values,m['answers'].str.len())
    m['context'] = idx
#     js['q_idx'] = ndx
    main = m[['id','question','context','answers']].set_index('id').reset_index()
    main['c_id'] = main['context'].factorize()[0]
    if verbose:
        print("shape of the dataframe is {}".format(main.shape))
        print("Done")
    return main

# %%
# training data
# input_file_path = '../input/train-v1.1.json'
input_file_path = '../train-v1.1.json'
record_path = ['data','paragraphs','qas','answers']
train = squad_json_to_dataframe_train(input_file_path=input_file_path,record_path=record_path)

# dev data
# input_file_path = '../input/dev-v1.1.json'
input_file_path = '../dev-v1.1.json'
record_path = ['data','paragraphs','qas','answers']
verbose = 0
dev = squad_json_to_dataframe_dev(input_file_path=input_file_path,record_path=record_path)
# Out:
# Reading the json file
# processing...
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   js = pd.io.json.json_normalize(file , record_path )
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   m = pd.io.json.json_normalize(file, record_path[:-1] )
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   r = pd.io.json.json_normalize(file,record_path[:-2])
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:24: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   main = pd.concat([ m[['id','question','context']].set_index('id'),js.set_index('q_idx')],1,sort=False).reset_index()
# shape of the dataframe is (87599, 6)
# Done
# Reading the json file
# processing...
# shape of the dataframe is (10570, 5)
# Done
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:45: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   js = pd.io.json.json_normalize(file , record_path )
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:46: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   m = pd.io.json.json_normalize(file, record_path[:-1] )
# /var/folders/8t/_x4qcscx7txf2l7h7tx1jwgr0000gn/T/ipykernel_61577/127156114.py:47: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   r = pd.io.json.json_normalize(file,record_path[:-2])

# %%
train.head()
# Out:
#                       index  \
# 0  5733be284776f41900661182
# 1  5733be284776f4190066117f
# 2  5733be284776f41900661180
# 3  5733be284776f41900661181
# 4  5733be284776f4190066117e
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              context  answer_start  \
# 0  Architecturally, the school has a Catholic cha...           515
# 1  Architecturally, the school has a Catholic cha...           188
# 2  Architecturally, the school has a Catholic cha...           279
# 3  Architecturally, the school has a Catholic cha...           381
# 4  Architecturally, the school has a Catholic cha...            92
#
#                                       text  c_id
# 0               Saint Bernadette Soubirous     0
# 1                a copper statue of Christ     0
# 2                        the Main Building     0
# 3  a Marian place of prayer and reflection     0
# 4       a golden statue of the Virgin Mary     0

# %%
dev.head()
# Out:
#                          id  \
# 0  56be4db0acb8001400a502ec
# 1  56be4db0acb8001400a502ed
# 2  56be4db0acb8001400a502ee
# 3  56be4db0acb8001400a502ef
# 4  56be4db0acb8001400a502f0
#
#                                             question  \
# 0  Which NFL team represented the AFC at Super Bo...
# 1  Which NFL team represented the NFC at Super Bo...
# 2                Where did Super Bowl 50 take place?
# 3                  Which NFL team won Super Bowl 50?
# 4  What color was used to emphasize the 50th anni...
#
#                                              context  \
# 0  Super Bowl 50 was an American football game to...
# 1  Super Bowl 50 was an American football game to...
# 2  Super Bowl 50 was an American football game to...
# 3  Super Bowl 50 was an American football game to...
# 4  Super Bowl 50 was an American football game to...
#
#                                              answers  c_id
# 0  [{'answer_start': 177, 'text': 'Denver Broncos...     0
# 1  [{'answer_start': 249, 'text': 'Carolina Panth...     0
# 2  [{'answer_start': 403, 'text': 'Santa Clara, C...     0
# 3  [{'answer_start': 177, 'text': 'Denver Broncos...     0
# 4  [{'answer_start': 488, 'text': 'gold'}, {'answ...     0

# %%
# Number of unique contexts
# train['context'].nunique()
print("Number of unique contexts in training data: ", train['context'].nunique())

# Number of unique questions
# train['question'].nunique()
print("Number of unique questions in training data: ", train['question'].nunique())
# Out:
# Number of unique contexts in training data:  18891
# Number of unique questions in training data:  87355

# %%
# Create text corpus of all contexts from training data and dev data (unique contexts)
train_context_corpus = train['context'].unique()
dev_context_corpus = dev['context'].unique()
context_corpus_combined = np.concatenate((train_context_corpus, dev_context_corpus), axis=0)
context_corpus = np.unique(context_corpus_combined)

# Show size of each corpus
print("Size of training context corpus: ", len(train_context_corpus))
print("Size of dev context corpus: ", len(dev_context_corpus))
print("Size of combined context corpus: ", len(context_corpus_combined))
print("Size of unique context corpus: ", len(context_corpus))
# Out:
# Size of training context corpus:  18891
# Size of dev context corpus:  2067
# Size of combined context corpus:  20958
# Size of unique context corpus:  20958

# %%
# Snapshots of the context corpus
print("First 5 contexts: ", context_corpus[:5])
# Out:
# First 5 contexts:  ["\n Australia: The event was held in Canberra, Australian Capital Territory on April 24, and covered around 16 km of Canberra's central areas, from Reconciliation Place to Commonwealth Park. Upon its arrival in Canberra, the Olympic flame was presented by Chinese officials to local Aboriginal elder Agnes Shea, of the Ngunnawal people. She, in turn, offered them a message stick, as a gift of peace and welcome. Hundreds of pro-Tibet protesters and thousands of Chinese students reportedly attended. Demonstrators and counter-demonstrators were kept apart by the Australian Federal Police. Preparations for the event were marred by a disagreement over the role of the Chinese flame attendants, with Australian and Chinese officials arguing publicly over their function and prerogatives during a press conference."
#  '\n China: In China, the torch was first welcomed by Politburo Standing Committee member Zhou Yongkang and State Councilor Liu Yandong. It was subsequently passed onto CPC General Secretary Hu Jintao. A call to boycott French hypermart Carrefour from May 1 began spreading through mobile text messaging and online chat rooms amongst the Chinese over the weekend from April 12, accusing the company\'s major shareholder, the LVMH Group, of donating funds to the Dalai Lama. There were also calls to extend the boycott to include French luxury goods and cosmetic products. According to the Washington Times on April 15, however, the Chinese government was attempting to "calm the situation" through censorship: "All comments posted on popular Internet forum Sohu.com relating to a boycott of Carrefour have been deleted." Chinese protesters organized boycotts of the French-owned retail chain Carrefour in major Chinese cities including Kunming, Hefei and Wuhan, accusing the French nation of pro-secessionist conspiracy and anti-Chinese racism. Some burned French flags, some added Nazism\'s Swastika to the French flag, and spread short online messages calling for large protests in front of French consulates and embassy. The Carrefour boycott was met with anti-boycott demonstrators who insisted on entering one of the Carrefour stores in Kunming, only to be blocked by boycotters wielding large Chinese flags and hit by water bottles. The BBC reported that hundreds of people demonstrated in Beijing, Wuhan, Hefei, Kunming and Qingdao.'
#  '\n France: The torch relay leg in Paris, held on April 7, began on the first level of the Eiffel Tower and finished at the Stade Charléty. The relay was initially supposed to cover 28 km, but it was shortened at the demand of Chinese officials following widespread protests by pro-Tibet and human rights activists, who repeatedly attempted to disrupt, hinder or halt the procession. A scheduled ceremony at the town hall was cancelled at the request of the Chinese authorities, and, also at the request of Chinese authorities, the torch finished the relay by bus instead of being carried by athletes. Paris City officials had announced plans to greet the Olympic flame with peaceful protest when the torch was to reach the French capital. The city government attached a banner reading "Paris defends human rights throughout the world" to the City Hall, in an attempt to promote values "of all humanity and of human rights." Members from Reporters Without Borders turned out in large numbers to protest. An estimated 3,000 French police protected the Olympic torch relay as it departed from the Eiffel Tower and criss-crossed Paris amid threat of protests. Widespread pro-Tibet protests, including an attempt by more than one demonstrator to extinguish the flame with water or fire extinguishers, prompted relay authorities to put out the flame five times (according to the police authorities in Paris) and load the torch onto a bus, at the demand of Chinese officials. This was later denied by the Chinese Ministry of Foreign Affairs, despite video footage broadcast by French television network France 2 which showed Chinese flame attendants extinguishing the torch. Backup flames are with the relay at all times to relight the torch. French judoka and torchbearer David Douillet expressed his annoyance at the Chinese flame attendants who extinguished the torch which he was about to hand over to Teddy Riner: "I understand they\'re afraid of everything, but this is just annoying. They extinguished the flame despite the fact that there was no risk, and they could see it and they knew it. I don\'t know why they did it."'
#  '\n Great Britain: The torch relay leg held in London, the host city of the 2012 Summer Olympics, on April 6 began at Wembley Stadium, passed through the City of London, and eventually ended at O2 Arena in the eastern part of the city. The 48 km (30 mi) leg took a total of seven and a half hours to complete, and attracted protests by pro-Tibetan independence and pro-Human Rights supporters, prompting changes to the planned route and an unscheduled move onto a bus, which was then briefly halted by protestors. Home Secretary Jacqui Smith has officially complained to Beijing Organising Committee about the conduct of the tracksuit-clad Chinese security guards. The Chinese officials, seen manhandling protesters, were described by both the London Mayor Ken Livingstone and Lord Coe, chairman of the London Olympic Committee as "thugs". A Metropolitan police briefing paper revealed that security for the torch relay cost £750,000 and the participation of the Chinese security team had been agreed in advance, despite the Mayor stating, "We did not know beforehand these thugs were from the security services. Had I known so, we would have said no."'
#  '\n India: Due to concerns about pro-Tibet protests, the relay through New Delhi on April 17 was cut to just 2.3 km (less than 1.5 miles), which was shared amongst 70 runners. It concluded at the India Gate. The event was peaceful due to the public not being allowed at the relay. A total of five intended torchbearers -Kiran Bedi, Soha Ali Khan, Sachin Tendulkar, Bhaichung Bhutia and Sunil Gavaskar- withdrew from the event, citing "personal reasons", or, in Bhutia\'s case, explicitly wishing to "stand by the people of Tibet and their struggle" and protest against the PRC "crackdown" in Tibet. Indian national football captain, Baichung Bhutia refused to take part in the Indian leg of the torch relay, citing concerns over Tibet. Bhutia, who is Sikkimese, is the first athlete to refuse to run with the torch. Indian film star Aamir Khan states on his personal blog that the "Olympic Games do not belong to China" and confirms taking part in the torch relay "with a prayer in his heart for the people of Tibet, and ... for all people across the world who are victims of human rights violations". Rahul Gandhi, son of the Congress President Sonia Gandhi and scion of the Nehru-Gandhi family, also refused to carry the torch.']

# %%
# Split context corpus
# NLTK Splitter
text_splitter = NLTKTextSplitter(chunk_size=500)

# Split context corpus into chunks of 500 words and keep track of the indices
context_corpus_split = [text_splitter.split_text(context) for context in context_corpus]
# Out:
# Created a chunk of size 618, which is longer than the specified 500
# Created a chunk of size 660, which is longer than the specified 500
# Created a chunk of size 768, which is longer than the specified 500
# Created a chunk of size 583, which is longer than the specified 500
# Created a chunk of size 569, which is longer than the specified 500
# Created a chunk of size 625, which is longer than the specified 500
# Created a chunk of size 628, which is longer than the specified 500
# Created a chunk of size 581, which is longer than the specified 500
# Created a chunk of size 527, which is longer than the specified 500
# Created a chunk of size 503, which is longer than the specified 500
# Created a chunk of size 511, which is longer than the specified 500
# Created a chunk of size 738, which is longer than the specified 500
# Created a chunk of size 595, which is longer than the specified 500
# Created a chunk of size 592, which is longer than the specified 500
# Created a chunk of size 611, which is longer than the specified 500
# Created a chunk of size 596, which is longer than the specified 500
# Created a chunk of size 565, which is longer than the specified 500
# Created a chunk of size 584, which is longer than the specified 500
# Created a chunk of size 565, which is longer than the specified 500
# Created a chunk of size 744, which is longer than the specified 500
# Created a chunk of size 530, which is longer than the specified 500
# Created a chunk of size 564, which is longer than the specified 500
# Created a chunk of size 542, which is longer than the specified 500
# Created a chunk of size 807, which is longer than the specified 500
# Created a chunk of size 512, which is longer than the specified 500
# Created a chunk of size 511, which is longer than the specified 500
# Created a chunk of size 517, which is longer than the specified 500
# Created a chunk of size 515, which is longer than the specified 500
# Created a chunk of size 521, which is longer than the specified 500
# Created a chunk of size 526, which is longer than the specified 500
# Created a chunk of size 536, which is longer than the specified 500
# Created a chunk of size 580, which is longer than the specified 500
# Created a chunk of size 1060, which is longer than the specified 500
# Created a chunk of size 523, which is longer than the specified 500
# Created a chunk of size 517, which is longer than the specified 500
# Created a chunk of size 504, which is longer than the specified 500
# Created a chunk of size 575, which is longer than the specified 500
# Created a chunk of size 553, which is longer than the specified 500
# Created a chunk of size 766, which is longer than the specified 500
# Created a chunk of size 525, which is longer than the specified 500
# Created a chunk of size 563, which is longer than the specified 500
# Created a chunk of size 1015, which is longer than the specified 500
# Created a chunk of size 684, which is longer than the specified 500
# Created a chunk of size 609, which is longer than the specified 500
# Created a chunk of size 540, which is longer than the specified 500
# Created a chunk of size 642, which is longer than the specified 500
# Created a chunk of size 506, which is longer than the specified 500
# Created a chunk of size 578, which is longer than the specified 500
# Created a chunk of size 543, which is longer than the specified 500
# Created a chunk of size 509, which is longer than the specified 500
# Created a chunk of size 740, which is longer than the specified 500
# Created a chunk of size 708, which is longer than the specified 500
# Created a chunk of size 624, which is longer than the specified 500
# Created a chunk of size 785, which is longer than the specified 500
# Created a chunk of size 681, which is longer than the specified 500
# Created a chunk of size 524, which is longer than the specified 500
# Created a chunk of size 738, which is longer than the specified 500
# Created a chunk of size 587, which is longer than the specified 500
# Created a chunk of size 515, which is longer than the specified 500
# Created a chunk of size 533, which is longer than the specified 500
# Created a chunk of size 521, which is longer than the specified 500
# Created a chunk of size 561, which is longer than the specified 500
# Created a chunk of size 582, which is longer than the specified 500
# Created a chunk of size 717, which is longer than the specified 500
# Created a chunk of size 781, which is longer than the specified 500
# Created a chunk of size 550, which is longer than the specified 500
# Created a chunk of size 613, which is longer than the specified 500
# Created a chunk of size 688, which is longer than the specified 500
# Created a chunk of size 511, which is longer than the specified 500
# Created a chunk of size 511, which is longer than the specified 500
# Created a chunk of size 548, which is longer than the specified 500
# Created a chunk of size 744, which is longer than the specified 500
# Created a chunk of size 629, which is longer than the specified 500
# Created a chunk of size 829, which is longer than the specified 500
# Created a chunk of size 649, which is longer than the specified 500
# Created a chunk of size 560, which is longer than the specified 500
# Created a chunk of size 512, which is longer than the specified 500
# Created a chunk of size 562, which is longer than the specified 500
# Created a chunk of size 519, which is longer than the specified 500
# Created a chunk of size 657, which is longer than the specified 500
# Created a chunk of size 523, which is longer than the specified 500
# Created a chunk of size 527, which is longer than the specified 500
# Created a chunk of size 1163, which is longer than the specified 500
# Created a chunk of size 604, which is longer than the specified 500
# Created a chunk of size 501, which is longer than the specified 500
# Created a chunk of size 662, which is longer than the specified 500
# Created a chunk of size 771, which is longer than the specified 500
# Created a chunk of size 630, which is longer than the specified 500
# Created a chunk of size 523, which is longer than the specified 500
# Created a chunk of size 946, which is longer than the specified 500
# Created a chunk of size 530, which is longer than the specified 500
# Created a chunk of size 751, which is longer than the specified 500
# Created a chunk of size 540, which is longer than the specified 500
# Created a chunk of size 522, which is longer than the specified 500
# Created a chunk of size 569, which is longer than the specified 500
# Created a chunk of size 753, which is longer than the specified 500
# Created a chunk of size 932, which is longer than the specified 500
# Created a chunk of size 604, which is longer than the specified 500
# Created a chunk of size 545, which is longer than the specified 500
# Created a chunk of size 793, which is longer than the specified 500
# Created a chunk of size 686, which is longer than the specified 500
# Created a chunk of size 689, which is longer than the specified 500
# Created a chunk of size 767, which is longer than the specified 500
# Created a chunk of size 501, which is longer than the specified 500
# Created a chunk of size 552, which is longer than the specified 500
# Created a chunk of size 536, which is longer than the specified 500
# Created a chunk of size 513, which is longer than the specified 500
# Created a chunk of size 548, which is longer than the specified 500
# Created a chunk of size 506, which is longer than the specified 500
# Created a chunk of size 532, which is longer than the specified 500
# Created a chunk of size 721, which is longer than the specified 500
# Created a chunk of size 646, which is longer than the specified 500
# Created a chunk of size 534, which is longer than the specified 500
# Created a chunk of size 528, which is longer than the specified 500
# Created a chunk of size 517, which is longer than the specified 500
# Created a chunk of size 567, which is longer than the specified 500
# Created a chunk of size 537, which is longer than the specified 500
# Created a chunk of size 522, which is longer than the specified 500
# Created a chunk of size 540, which is longer than the specified 500
# Created a chunk of size 516, which is longer than the specified 500
# Created a chunk of size 590, which is longer than the specified 500
# Created a chunk of size 617, which is longer than the specified 500
# Created a chunk of size 547, which is longer than the specified 500
# Created a chunk of size 503, which is longer than the specified 500
# Created a chunk of size 558, which is longer than the specified 500
# Created a chunk of size 521, which is longer than the specified 500
# Created a chunk of size 618, which is longer than the specified 500
# Created a chunk of size 545, which is longer than the specified 500
# Created a chunk of size 939, which is longer than the specified 500
# Created a chunk of size 526, which is longer than the specified 500
# Created a chunk of size 618, which is longer than the specified 500
# Created a chunk of size 555, which is longer than the specified 500
# Created a chunk of size 620, which is longer than the specified 500
# Created a chunk of size 682, which is longer than the specified 500
# Created a chunk of size 543, which is longer than the specified 500
# Created a chunk of size 736, which is longer than the specified 500
# Created a chunk of size 685, which is longer than the specified 500
# Created a chunk of size 528, which is longer than the specified 500
# Created a chunk of size 502, which is longer than the specified 500
# Created a chunk of size 514, which is longer than the specified 500
# Created a chunk of size 512, which is longer than the specified 500
# Created a chunk of size 638, which is longer than the specified 500
# Created a chunk of size 557, which is longer than the specified 500
# Created a chunk of size 517, which is longer than the specified 500
# Created a chunk of size 542, which is longer than the specified 500
# Created a chunk of size 674, which is longer than the specified 500
# Created a chunk of size 635, which is longer than the specified 500
# Created a chunk of size 521, which is longer than the specified 500
# Created a chunk of size 1412, which is longer than the specified 500
# Created a chunk of size 565, which is longer than the specified 500
# Created a chunk of size 505, which is longer than the specified 500
# Created a chunk of size 502, which is longer than the specified 500
# Created a chunk of size 525, which is longer than the specified 500
# Created a chunk of size 540, which is longer than the specified 500
# Created a chunk of size 541, which is longer than the specified 500
# Created a chunk of size 553, which is longer than the specified 500
# Created a chunk of size 559, which is longer than the specified 500
# Created a chunk of size 525, which is longer than the specified 500
# Created a chunk of size 788, which is longer than the specified 500

# %%
# Show first 5 chunks
context_corpus_split[:5]
# Out:
# [["Australia: The event was held in Canberra, Australian Capital Territory on April 24, and covered around 16 km of Canberra's central areas, from Reconciliation Place to Commonwealth Park.\n\nUpon its arrival in Canberra, the Olympic flame was presented by Chinese officials to local Aboriginal elder Agnes Shea, of the Ngunnawal people.\n\nShe, in turn, offered them a message stick, as a gift of peace and welcome.",
#   'She, in turn, offered them a message stick, as a gift of peace and welcome.\n\nHundreds of pro-Tibet protesters and thousands of Chinese students reportedly attended.\n\nDemonstrators and counter-demonstrators were kept apart by the Australian Federal Police.\n\nPreparations for the event were marred by a disagreement over the role of the Chinese flame attendants, with Australian and Chinese officials arguing publicly over their function and prerogatives during a press conference.'],
#  ["China: In China, the torch was first welcomed by Politburo Standing Committee member Zhou Yongkang and State Councilor Liu Yandong.\n\nIt was subsequently passed onto CPC General Secretary Hu Jintao.\n\nA call to boycott French hypermart Carrefour from May 1 began spreading through mobile text messaging and online chat rooms amongst the Chinese over the weekend from April 12, accusing the company's major shareholder, the LVMH Group, of donating funds to the Dalai Lama.",
#   'There were also calls to extend the boycott to include French luxury goods and cosmetic products.\n\nAccording to the Washington Times on April 15, however, the Chinese government was attempting to "calm the situation" through censorship: "All comments posted on popular Internet forum Sohu.com relating to a boycott of Carrefour have been deleted."',
#   "Chinese protesters organized boycotts of the French-owned retail chain Carrefour in major Chinese cities including Kunming, Hefei and Wuhan, accusing the French nation of pro-secessionist conspiracy and anti-Chinese racism.\n\nSome burned French flags, some added Nazism's Swastika to the French flag, and spread short online messages calling for large protests in front of French consulates and embassy.",
#   "Some burned French flags, some added Nazism's Swastika to the French flag, and spread short online messages calling for large protests in front of French consulates and embassy.\n\nThe Carrefour boycott was met with anti-boycott demonstrators who insisted on entering one of the Carrefour stores in Kunming, only to be blocked by boycotters wielding large Chinese flags and hit by water bottles.\n\nThe BBC reported that hundreds of people demonstrated in Beijing, Wuhan, Hefei, Kunming and Qingdao."],
#  ['France: The torch relay leg in Paris, held on April 7, began on the first level of the Eiffel Tower and finished at the Stade Charléty.\n\nThe relay was initially supposed to cover 28 km, but it was shortened at the demand of Chinese officials following widespread protests by pro-Tibet and human rights activists, who repeatedly attempted to disrupt, hinder or halt the procession.',
#   'A scheduled ceremony at the town hall was cancelled at the request of the Chinese authorities, and, also at the request of Chinese authorities, the torch finished the relay by bus instead of being carried by athletes.\n\nParis City officials had announced plans to greet the Olympic flame with peaceful protest when the torch was to reach the French capital.',
#   'Paris City officials had announced plans to greet the Olympic flame with peaceful protest when the torch was to reach the French capital.\n\nThe city government attached a banner reading "Paris defends human rights throughout the world" to the City Hall, in an attempt to promote values "of all humanity and of human rights."\n\nMembers from Reporters Without Borders turned out in large numbers to protest.',
#   'Members from Reporters Without Borders turned out in large numbers to protest.\n\nAn estimated 3,000 French police protected the Olympic torch relay as it departed from the Eiffel Tower and criss-crossed Paris amid threat of protests.',
#   'An estimated 3,000 French police protected the Olympic torch relay as it departed from the Eiffel Tower and criss-crossed Paris amid threat of protests.\n\nWidespread pro-Tibet protests, including an attempt by more than one demonstrator to extinguish the flame with water or fire extinguishers, prompted relay authorities to put out the flame five times (according to the police authorities in Paris) and load the torch onto a bus, at the demand of Chinese officials.',
#   'This was later denied by the Chinese Ministry of Foreign Affairs, despite video footage broadcast by French television network France 2 which showed Chinese flame attendants extinguishing the torch.\n\nBackup flames are with the relay at all times to relight the torch.',
#   'Backup flames are with the relay at all times to relight the torch.\n\nFrench judoka and torchbearer David Douillet expressed his annoyance at the Chinese flame attendants who extinguished the torch which he was about to hand over to Teddy Riner: "I understand they\'re afraid of everything, but this is just annoying.\n\nThey extinguished the flame despite the fact that there was no risk, and they could see it and they knew it.\n\nI don\'t know why they did it."'],
#  ['Great Britain: The torch relay leg held in London, the host city of the 2012 Summer Olympics, on April 6 began at Wembley Stadium, passed through the City of London, and eventually ended at O2 Arena in the eastern part of the city.',
#   'The 48 km (30 mi) leg took a total of seven and a half hours to complete, and attracted protests by pro-Tibetan independence and pro-Human Rights supporters, prompting changes to the planned route and an unscheduled move onto a bus, which was then briefly halted by protestors.\n\nHome Secretary Jacqui Smith has officially complained to Beijing Organising Committee about the conduct of the tracksuit-clad Chinese security guards.',
#   'Home Secretary Jacqui Smith has officially complained to Beijing Organising Committee about the conduct of the tracksuit-clad Chinese security guards.\n\nThe Chinese officials, seen manhandling protesters, were described by both the London Mayor Ken Livingstone and Lord Coe, chairman of the London Olympic Committee as "thugs".',
#   'The Chinese officials, seen manhandling protesters, were described by both the London Mayor Ken Livingstone and Lord Coe, chairman of the London Olympic Committee as "thugs".\n\nA Metropolitan police briefing paper revealed that security for the torch relay cost £750,000 and the participation of the Chinese security team had been agreed in advance, despite the Mayor stating, "We did not know beforehand these thugs were from the security services.\n\nHad I known so, we would have said no."'],
#  ['India: Due to concerns about pro-Tibet protests, the relay through New Delhi on April 17 was cut to just 2.3 km (less than 1.5 miles), which was shared amongst 70 runners.\n\nIt concluded at the India Gate.\n\nThe event was peaceful due to the public not being allowed at the relay.',
#   'It concluded at the India Gate.\n\nThe event was peaceful due to the public not being allowed at the relay.\n\nA total of five intended torchbearers -Kiran Bedi, Soha Ali Khan, Sachin Tendulkar, Bhaichung Bhutia and Sunil Gavaskar- withdrew from the event, citing "personal reasons", or, in Bhutia\'s case, explicitly wishing to "stand by the people of Tibet and their struggle" and protest against the PRC "crackdown" in Tibet.',
#   'Indian national football captain, Baichung Bhutia refused to take part in the Indian leg of the torch relay, citing concerns over Tibet.\n\nBhutia, who is Sikkimese, is the first athlete to refuse to run with the torch.',
#   'Bhutia, who is Sikkimese, is the first athlete to refuse to run with the torch.\n\nIndian film star Aamir Khan states on his personal blog that the "Olympic Games do not belong to China" and confirms taking part in the torch relay "with a prayer in his heart for the people of Tibet, and ... for all people across the world who are victims of human rights violations".\n\nRahul Gandhi, son of the Congress President Sonia Gandhi and scion of the Nehru-Gandhi family, also refused to carry the torch.']]

# %%
import time

def embed_chunks(context_corpus_split, batch_size=100, retries=3, delay=5):
    to_upsert = []

    for i, context_chunks in enumerate(context_corpus_split):
        print(f"Processing context {i+1} of {len(context_corpus_split)}")  # Print current context index
        for j, chunk in enumerate(context_chunks):
            for attempt in range(retries):
                try:
                    # Create an embedding for the chunk text
                    res = openai.Embedding.create(
                        input=[chunk],
                        engine="text-embedding-ada-002"
                    )
                    embedding = res['data'][0]['embedding'] 

                    # Prepare the data for upserting
                    id = f"context_{i}_{j}"
                    meta = {'text': chunk}
                    to_upsert.append((id, embedding, meta))

                    # Upsert in batches
                    if len(to_upsert) >= batch_size:
                        index.upsert(vectors=to_upsert)
                        to_upsert = []  # Reset the list

                    # If the request was successful, break the loop
                    break
                except openai.ApiError as e:
                    if attempt < retries - 1:  # If this is not the last attempt
                        print(f"Error: {e}. Retrying in {delay} seconds...")
                        time.sleep(delay)  # Wait for a while before retrying
                    else:
                        raise  # If this was the last attempt, re-raise the exception

    # Upsert any remaining embeddings
    if to_upsert:
        index.upsert(vectors=to_upsert)

    print(f"{len(to_upsert)} chunks embedded successfully!")

# Call the function
embed_chunks(context_corpus_split)
# Out:
# Processing context 1 of 20958
# Processing context 2 of 20958
# Processing context 3 of 20958
# Processing context 4 of 20958
# Processing context 5 of 20958
# Processing context 6 of 20958
# Processing context 7 of 20958
# Processing context 8 of 20958
# Processing context 9 of 20958
# Processing context 10 of 20958
# Processing context 11 of 20958
# Processing context 12 of 20958
# Processing context 13 of 20958
# Processing context 14 of 20958
# Processing context 15 of 20958
# Processing context 16 of 20958
# Processing context 17 of 20958
# Processing context 18 of 20958
# Processing context 19 of 20958
# Processing context 20 of 20958
# Processing context 21 of 20958
# Processing context 22 of 20958
# Processing context 23 of 20958
# Processing context 24 of 20958
# Processing context 25 of 20958
# Processing context 26 of 20958
# Processing context 27 of 20958
# Processing context 28 of 20958
# Processing context 29 of 20958
# Processing context 30 of 20958
# Processing context 31 of 20958
# Processing context 32 of 20958
# Processing context 33 of 20958
# Processing context 34 of 20958
# Processing context 35 of 20958
# Processing context 36 of 20958
# Processing context 37 of 20958
# Processing context 38 of 20958
# Processing context 39 of 20958
# Processing context 40 of 20958
# Processing context 41 of 20958
# Processing context 42 of 20958
# Processing context 43 of 20958
# Processing context 44 of 20958
# Processing context 45 of 20958
# Processing context 46 of 20958
# Processing context 47 of 20958
# Processing context 48 of 20958
# Processing context 49 of 20958
# Processing context 50 of 20958
# Processing context 51 of 20958
# Processing context 52 of 20958
# Processing context 53 of 20958
# Processing context 54 of 20958
# Processing context 55 of 20958
# Processing context 56 of 20958
# Processing context 57 of 20958
# Processing context 58 of 20958
# Processing context 59 of 20958
# Processing context 60 of 20958
# Processing context 61 of 20958
# Processing context 62 of 20958
# Processing context 63 of 20958
# Processing context 64 of 20958
# Processing context 65 of 20958
# Processing context 66 of 20958
# Processing context 67 of 20958
# Processing context 68 of 20958
# Processing context 69 of 20958
# Processing context 70 of 20958
# Processing context 71 of 20958
# Processing context 72 of 20958
# Processing context 73 of 20958
# Processing context 74 of 20958
# Processing context 75 of 20958
# Processing context 76 of 20958
# Processing context 77 of 20958
# Processing context 78 of 20958
# Processing context 79 of 20958
# Processing context 80 of 20958
# Processing context 81 of 20958
# Processing context 82 of 20958
# Processing context 83 of 20958
# Processing context 84 of 20958
# Processing context 85 of 20958
# Processing context 86 of 20958
# Processing context 87 of 20958
# Processing context 88 of 20958
# Processing context 89 of 20958
# Processing context 90 of 20958
# Processing context 91 of 20958
# Processing context 92 of 20958
# Processing context 93 of 20958
# Processing context 94 of 20958
# Processing context 95 of 20958
# Processing context 96 of 20958
# Processing context 97 of 20958
# Processing context 98 of 20958
# Processing context 99 of 20958
# Processing context 100 of 20958
# Processing context 101 of 20958
# Processing context 102 of 20958
# Processing context 103 of 20958
# Processing context 104 of 20958
# Processing context 105 of 20958
# Processing context 106 of 20958
# Processing context 107 of 20958
# Processing context 108 of 20958
# Processing context 109 of 20958
# Processing context 110 of 20958
# Processing context 111 of 20958
# Processing context 112 of 20958
# Processing context 113 of 20958
# Processing context 114 of 20958
# Processing context 115 of 20958
# Processing context 116 of 20958
# Processing context 117 of 20958
# Processing context 118 of 20958
# Processing context 119 of 20958
# Processing context 120 of 20958
# Processing context 121 of 20958
# Processing context 122 of 20958
# Processing context 123 of 20958
# Processing context 124 of 20958
# Processing context 125 of 20958
# Processing context 126 of 20958
# Processing context 127 of 20958
# Processing context 128 of 20958
# Processing context 129 of 20958
# Processing context 130 of 20958
# Processing context 131 of 20958
# Processing context 132 of 20958
# Processing context 133 of 20958
# Processing context 134 of 20958
# Processing context 135 of 20958
# Processing context 136 of 20958
# Processing context 137 of 20958
# Processing context 138 of 20958
# Processing context 139 of 20958
# Processing context 140 of 20958
# Processing context 141 of 20958
# Processing context 142 of 20958
# Processing context 143 of 20958
# Processing context 144 of 20958
# Processing context 145 of 20958
# Processing context 146 of 20958
# Processing context 147 of 20958
# Processing context 148 of 20958
# Processing context 149 of 20958
# Processing context 150 of 20958
# Processing context 151 of 20958
# Processing context 152 of 20958
# Processing context 153 of 20958
# Processing context 154 of 20958
# Processing context 155 of 20958
# Processing context 156 of 20958
# Processing context 157 of 20958
# Processing context 158 of 20958
# Processing context 159 of 20958
# Processing context 160 of 20958
# Processing context 161 of 20958
# Processing context 162 of 20958
# Processing context 163 of 20958
# Processing context 164 of 20958
# Processing context 165 of 20958
# Processing context 166 of 20958
# Processing context 167 of 20958
# Processing context 168 of 20958
# Processing context 169 of 20958
# Processing context 170 of 20958
# Processing context 171 of 20958
# Processing context 172 of 20958
# Processing context 173 of 20958
# Processing context 174 of 20958
# Processing context 175 of 20958
# Processing context 176 of 20958
# Processing context 177 of 20958
# Processing context 178 of 20958
# Processing context 179 of 20958
# Processing context 180 of 20958
# Processing context 181 of 20958
# Processing context 182 of 20958
# Processing context 183 of 20958
# Processing context 184 of 20958
# Processing context 185 of 20958
# Processing context 186 of 20958
# Processing context 187 of 20958
# Processing context 188 of 20958
# Processing context 189 of 20958
# Processing context 190 of 20958
# Processing context 191 of 20958
# Processing context 192 of 20958
# Processing context 193 of 20958
# Processing context 194 of 20958
# Processing context 195 of 20958
# Processing context 196 of 20958
# Processing context 197 of 20958
# Processing context 198 of 20958
# Processing context 199 of 20958
# Processing context 200 of 20958
# Processing context 201 of 20958
# Processing context 202 of 20958
# Processing context 203 of 20958
# Processing context 204 of 20958
# Processing context 205 of 20958
# Processing context 206 of 20958
# Processing context 207 of 20958
# Processing context 208 of 20958
# Processing context 209 of 20958
# Processing context 210 of 20958
# Processing context 211 of 20958
# Processing context 212 of 20958
# Processing context 213 of 20958
# Processing context 214 of 20958
# Processing context 215 of 20958
# Processing context 216 of 20958
# Processing context 217 of 20958
# Processing context 218 of 20958
# Processing context 219 of 20958
# Processing context 220 of 20958
# Processing context 221 of 20958
# Processing context 222 of 20958
# Processing context 223 of 20958
# Processing context 224 of 20958
# Processing context 225 of 20958
# Processing context 226 of 20958
# Processing context 227 of 20958
# Processing context 228 of 20958
# Processing context 229 of 20958
# Processing context 230 of 20958
# Processing context 231 of 20958
# Processing context 232 of 20958
# Processing context 233 of 20958
# Processing context 234 of 20958
# Processing context 235 of 20958
# Processing context 236 of 20958
# Processing context 237 of 20958
# Processing context 238 of 20958
# Processing context 239 of 20958
# Processing context 240 of 20958
# Processing context 241 of 20958
# Processing context 242 of 20958
# Processing context 243 of 20958
# Processing context 244 of 20958
# Processing context 245 of 20958
# Processing context 246 of 20958
# Processing context 247 of 20958
# Processing context 248 of 20958
# Processing context 249 of 20958
# Processing context 250 of 20958
# Processing context 251 of 20958
# Processing context 252 of 20958
# Processing context 253 of 20958
# Processing context 254 of 20958
# Processing context 255 of 20958
# Processing context 256 of 20958
# Processing context 257 of 20958
# Processing context 258 of 20958
# Processing context 259 of 20958
# Processing context 260 of 20958
# Processing context 261 of 20958
# Processing context 262 of 20958
# Processing context 263 of 20958
# Processing context 264 of 20958
# Processing context 265 of 20958
# Processing context 266 of 20958
# Processing context 267 of 20958
# Processing context 268 of 20958
# Processing context 269 of 20958
# Processing context 270 of 20958
# Processing context 271 of 20958
# Processing context 272 of 20958
# Processing context 273 of 20958
# Processing context 274 of 20958
# Processing context 275 of 20958
# Processing context 276 of 20958
# Processing context 277 of 20958
# Processing context 278 of 20958
# Processing context 279 of 20958
# Processing context 280 of 20958
# Processing context 281 of 20958
# Processing context 282 of 20958
# Processing context 283 of 20958
# Processing context 284 of 20958
# Processing context 285 of 20958
# Processing context 286 of 20958
# Processing context 287 of 20958
# Processing context 288 of 20958
# Processing context 289 of 20958
# Processing context 290 of 20958
# Processing context 291 of 20958
# Processing context 292 of 20958
# Processing context 293 of 20958
# Processing context 294 of 20958
# Processing context 295 of 20958
# Processing context 296 of 20958
# Processing context 297 of 20958
# Processing context 298 of 20958
# Processing context 299 of 20958
# Processing context 300 of 20958
# Processing context 301 of 20958
# Processing context 302 of 20958
# Processing context 303 of 20958
# Processing context 304 of 20958
# Processing context 305 of 20958
# Processing context 306 of 20958
# Processing context 307 of 20958
# Processing context 308 of 20958
# Processing context 309 of 20958
# Processing context 310 of 20958
# Processing context 311 of 20958
# Processing context 312 of 20958
# Processing context 313 of 20958
# Processing context 314 of 20958
# Processing context 315 of 20958
# Processing context 316 of 20958
# Processing context 317 of 20958
# Processing context 318 of 20958
# Processing context 319 of 20958
# Processing context 320 of 20958
# Processing context 321 of 20958
# Processing context 322 of 20958
# Processing context 323 of 20958
# Processing context 324 of 20958
# Processing context 325 of 20958
# Processing context 326 of 20958
# Processing context 327 of 20958
# Processing context 328 of 20958
# Processing context 329 of 20958
# Processing context 330 of 20958
# Processing context 331 of 20958
# Processing context 332 of 20958
# Processing context 333 of 20958
# Processing context 334 of 20958
# Processing context 335 of 20958
# Processing context 336 of 20958
# Processing context 337 of 20958
# Processing context 338 of 20958
# Processing context 339 of 20958
# Processing context 340 of 20958
# Processing context 341 of 20958
# Processing context 342 of 20958
# Processing context 343 of 20958
# Processing context 344 of 20958
# Processing context 345 of 20958
# Processing context 346 of 20958
# Processing context 347 of 20958
# Processing context 348 of 20958
# Processing context 349 of 20958
# Processing context 350 of 20958
# Processing context 351 of 20958
# Processing context 352 of 20958
# Processing context 353 of 20958
# Processing context 354 of 20958
# Processing context 355 of 20958
# Processing context 356 of 20958
# Processing context 357 of 20958
# Processing context 358 of 20958
# Processing context 359 of 20958
# Processing context 360 of 20958
# Processing context 361 of 20958
# Processing context 362 of 20958
# Processing context 363 of 20958
# Processing context 364 of 20958
# Processing context 365 of 20958
# Processing context 366 of 20958
# Processing context 367 of 20958
# Processing context 368 of 20958
# Processing context 369 of 20958
# Processing context 370 of 20958
# Processing context 371 of 20958
# Processing context 372 of 20958
# Processing context 373 of 20958
# Processing context 374 of 20958
# Processing context 375 of 20958
# Processing context 376 of 20958
# Processing context 377 of 20958
# Processing context 378 of 20958
# Processing context 379 of 20958
# Processing context 380 of 20958
# Processing context 381 of 20958
# Processing context 382 of 20958
# Processing context 383 of 20958
# Processing context 384 of 20958
# Processing context 385 of 20958
# Processing context 386 of 20958
# Processing context 387 of 20958
# Processing context 388 of 20958
# Processing context 389 of 20958
# Processing context 390 of 20958
# Processing context 391 of 20958
# Processing context 392 of 20958
# Processing context 393 of 20958
# Processing context 394 of 20958
# Processing context 395 of 20958
# Processing context 396 of 20958
# Processing context 397 of 20958
# Processing context 398 of 20958
# Processing context 399 of 20958
# Processing context 400 of 20958
# Processing context 401 of 20958
# Processing context 402 of 20958
# Processing context 403 of 20958
# Processing context 404 of 20958
# Processing context 405 of 20958
# Processing context 406 of 20958
# Processing context 407 of 20958
# Processing context 408 of 20958
# Processing context 409 of 20958
# Processing context 410 of 20958
# Processing context 411 of 20958
# Processing context 412 of 20958
# Processing context 413 of 20958
# Processing context 414 of 20958
# Processing context 415 of 20958
# Processing context 416 of 20958
# Processing context 417 of 20958
# Processing context 418 of 20958
# Processing context 419 of 20958
# Processing context 420 of 20958
# Processing context 421 of 20958
# Processing context 422 of 20958
# Processing context 423 of 20958
# Processing context 424 of 20958
# Processing context 425 of 20958
# Processing context 426 of 20958
# Processing context 427 of 20958
# Processing context 428 of 20958
# Processing context 429 of 20958
# Processing context 430 of 20958
# Processing context 431 of 20958
# Processing context 432 of 20958
# Processing context 433 of 20958
# Processing context 434 of 20958
# Processing context 435 of 20958
# Processing context 436 of 20958
# Processing context 437 of 20958
# Processing context 438 of 20958
# Processing context 439 of 20958
# Processing context 440 of 20958
# Processing context 441 of 20958
# Processing context 442 of 20958
# Processing context 443 of 20958
# Processing context 444 of 20958
# Processing context 445 of 20958
# Processing context 446 of 20958
# Processing context 447 of 20958
# Processing context 448 of 20958
# Processing context 449 of 20958
# Processing context 450 of 20958
# Processing context 451 of 20958
# Processing context 452 of 20958
# Processing context 453 of 20958
# Processing context 454 of 20958
# Processing context 455 of 20958
# Processing context 456 of 20958
# Processing context 457 of 20958
# Processing context 458 of 20958
# Processing context 459 of 20958
# Processing context 460 of 20958
# Processing context 461 of 20958
# Processing context 462 of 20958
# Processing context 463 of 20958
# Processing context 464 of 20958
# Processing context 465 of 20958
# Processing context 466 of 20958
# Processing context 467 of 20958
# Processing context 468 of 20958
# Processing context 469 of 20958
# Processing context 470 of 20958
# Processing context 471 of 20958
# Processing context 472 of 20958
# Processing context 473 of 20958
# Processing context 474 of 20958
# Processing context 475 of 20958
# Processing context 476 of 20958
# Processing context 477 of 20958
# Processing context 478 of 20958
# Processing context 479 of 20958
# Processing context 480 of 20958
# Processing context 481 of 20958
# Processing context 482 of 20958
# Processing context 483 of 20958
# Processing context 484 of 20958
# Processing context 485 of 20958
# Processing context 486 of 20958
# Processing context 487 of 20958
# Processing context 488 of 20958
# Processing context 489 of 20958
# Processing context 490 of 20958
# Processing context 491 of 20958
# Processing context 492 of 20958
# Processing context 493 of 20958
# Processing context 494 of 20958
# Processing context 495 of 20958
# Processing context 496 of 20958
# Processing context 497 of 20958
# Processing context 498 of 20958
# Processing context 499 of 20958
# Processing context 500 of 20958
# Processing context 501 of 20958
# Processing context 502 of 20958
# Processing context 503 of 20958
# Processing context 504 of 20958
# Processing context 505 of 20958
# Processing context 506 of 20958
# Processing context 507 of 20958
# Processing context 508 of 20958
# Processing context 509 of 20958
# Processing context 510 of 20958
# Processing context 511 of 20958
# Processing context 512 of 20958
# Processing context 513 of 20958
# Processing context 514 of 20958
# Processing context 515 of 20958
# Processing context 516 of 20958
# Processing context 517 of 20958
# Processing context 518 of 20958
# Processing context 519 of 20958
# Processing context 520 of 20958
# Processing context 521 of 20958
# Processing context 522 of 20958
# Processing context 523 of 20958
# Processing context 524 of 20958
# Processing context 525 of 20958
# Processing context 526 of 20958
# Processing context 527 of 20958
# Processing context 528 of 20958
# Processing context 529 of 20958
# Processing context 530 of 20958
# Processing context 531 of 20958
# Processing context 532 of 20958
# Processing context 533 of 20958
# Processing context 534 of 20958
# Processing context 535 of 20958
# Processing context 536 of 20958
# Processing context 537 of 20958
# Processing context 538 of 20958
# Processing context 539 of 20958
# Processing context 540 of 20958
# Processing context 541 of 20958
# Processing context 542 of 20958
# Processing context 543 of 20958
# Processing context 544 of 20958
# Processing context 545 of 20958
# Processing context 546 of 20958
# Processing context 547 of 20958
# Processing context 548 of 20958
# Processing context 549 of 20958
# Processing context 550 of 20958
# Processing context 551 of 20958
# Processing context 552 of 20958
# Processing context 553 of 20958
# Processing context 554 of 20958
# Processing context 555 of 20958
# Processing context 556 of 20958
# Processing context 557 of 20958
# Processing context 558 of 20958
# Processing context 559 of 20958
# Processing context 560 of 20958
# Processing context 561 of 20958
# Processing context 562 of 20958
# Processing context 563 of 20958
# Processing context 564 of 20958
# Processing context 565 of 20958
# Processing context 566 of 20958
# Processing context 567 of 20958
# Processing context 568 of 20958
# Processing context 569 of 20958
# Processing context 570 of 20958
# Processing context 571 of 20958
# Processing context 572 of 20958
# Processing context 573 of 20958
# Processing context 574 of 20958
# Processing context 575 of 20958
# Processing context 576 of 20958
# Processing context 577 of 20958
# Processing context 578 of 20958
# Processing context 579 of 20958
# Processing context 580 of 20958
# Processing context 581 of 20958
# Processing context 582 of 20958
# Processing context 583 of 20958
# Processing context 584 of 20958
# Processing context 585 of 20958
# Processing context 586 of 20958
# Processing context 587 of 20958
# Processing context 588 of 20958
# Processing context 589 of 20958
# Processing context 590 of 20958
# Processing context 591 of 20958
# Processing context 592 of 20958
# Processing context 593 of 20958
# Processing context 594 of 20958
# Processing context 595 of 20958
# Processing context 596 of 20958
# Processing context 597 of 20958
# Processing context 598 of 20958
# Processing context 599 of 20958
# Processing context 600 of 20958
# Processing context 601 of 20958
# Processing context 602 of 20958
# Processing context 603 of 20958
# Processing context 604 of 20958
# Processing context 605 of 20958
# Processing context 606 of 20958
# Processing context 607 of 20958
# Processing context 608 of 20958
# Processing context 609 of 20958
# Processing context 610 of 20958
# Processing context 611 of 20958
# Processing context 612 of 20958
# Processing context 613 of 20958
# Processing context 614 of 20958
# Processing context 615 of 20958
# Processing context 616 of 20958
# Processing context 617 of 20958
# Processing context 618 of 20958
# Processing context 619 of 20958
# Processing context 620 of 20958
# Processing context 621 of 20958
# Processing context 622 of 20958
# Processing context 623 of 20958
# Processing context 624 of 20958
# Processing context 625 of 20958
# Processing context 626 of 20958
# Processing context 627 of 20958
# Processing context 628 of 20958
# Processing context 629 of 20958
# Processing context 630 of 20958
# Processing context 631 of 20958
# Processing context 632 of 20958
# Processing context 633 of 20958
# Processing context 634 of 20958
# Processing context 635 of 20958
# Processing context 636 of 20958
# Processing context 637 of 20958
# Processing context 638 of 20958
# Processing context 639 of 20958
# Processing context 640 of 20958
# Processing context 641 of 20958
# Processing context 642 of 20958
# Processing context 643 of 20958
# Processing context 644 of 20958
# Processing context 645 of 20958
# Processing context 646 of 20958
# Processing context 647 of 20958
# Processing context 648 of 20958
# Processing context 649 of 20958
# Processing context 650 of 20958
# Processing context 651 of 20958
# Processing context 652 of 20958
# Processing context 653 of 20958
# Processing context 654 of 20958
# Processing context 655 of 20958
# Processing context 656 of 20958
# Processing context 657 of 20958
# Processing context 658 of 20958
# Processing context 659 of 20958
# Processing context 660 of 20958
# Processing context 661 of 20958
# Processing context 662 of 20958
# Processing context 663 of 20958
# Processing context 664 of 20958
# Processing context 665 of 20958
# Processing context 666 of 20958
# Processing context 667 of 20958
# Processing context 668 of 20958
# Processing context 669 of 20958
# Processing context 670 of 20958
# Processing context 671 of 20958
# Processing context 672 of 20958
# Processing context 673 of 20958
# Processing context 674 of 20958
# Processing context 675 of 20958
# Processing context 676 of 20958
# Processing context 677 of 20958
# Processing context 678 of 20958
# Processing context 679 of 20958
# Processing context 680 of 20958
# Processing context 681 of 20958
# Processing context 682 of 20958
# Processing context 683 of 20958
# Processing context 684 of 20958
# Processing context 685 of 20958
# Processing context 686 of 20958
# Processing context 687 of 20958
# Processing context 688 of 20958
# Processing context 689 of 20958
# Processing context 690 of 20958
# Processing context 691 of 20958
# Processing context 692 of 20958
# Processing context 693 of 20958
# Processing context 694 of 20958
# Processing context 695 of 20958
# Processing context 696 of 20958
# Processing context 697 of 20958
# Processing context 698 of 20958
# Processing context 699 of 20958
# Processing context 700 of 20958
# Processing context 701 of 20958
# Processing context 702 of 20958
# Processing context 703 of 20958
# Processing context 704 of 20958
# Processing context 705 of 20958
# Processing context 706 of 20958
# Processing context 707 of 20958
# Processing context 708 of 20958
# Processing context 709 of 20958
# Processing context 710 of 20958
# Processing context 711 of 20958
# Processing context 712 of 20958
# Processing context 713 of 20958
# Processing context 714 of 20958
# Processing context 715 of 20958
# Processing context 716 of 20958
# Processing context 717 of 20958
# Processing context 718 of 20958
# Processing context 719 of 20958
# Processing context 720 of 20958
# Processing context 721 of 20958
# Processing context 722 of 20958
# Processing context 723 of 20958
# Processing context 724 of 20958
# Processing context 725 of 20958
# Processing context 726 of 20958
# Processing context 727 of 20958
# Processing context 728 of 20958
# Processing context 729 of 20958
# Processing context 730 of 20958
# Processing context 731 of 20958
# Processing context 732 of 20958
# Processing context 733 of 20958
# Processing context 734 of 20958
# Processing context 735 of 20958
# Processing context 736 of 20958
# Processing context 737 of 20958
# Processing context 738 of 20958
# Processing context 739 of 20958
# Processing context 740 of 20958
# Processing context 741 of 20958
# Processing context 742 of 20958
# Processing context 743 of 20958
# Processing context 744 of 20958
# Processing context 745 of 20958
# Processing context 746 of 20958
# Processing context 747 of 20958
# Processing context 748 of 20958
# Processing context 749 of 20958
# Processing context 750 of 20958
# Processing context 751 of 20958
# Processing context 752 of 20958
# Processing context 753 of 20958
# Processing context 754 of 20958
# Processing context 755 of 20958
# Processing context 756 of 20958
# Processing context 757 of 20958
# Processing context 758 of 20958
# Processing context 759 of 20958
# Processing context 760 of 20958
# Processing context 761 of 20958
# Processing context 762 of 20958
# Processing context 763 of 20958
# Processing context 764 of 20958
# Processing context 765 of 20958
# Processing context 766 of 20958
# Processing context 767 of 20958
# Processing context 768 of 20958
# Processing context 769 of 20958
# Processing context 770 of 20958
# Processing context 771 of 20958
# Processing context 772 of 20958
# Processing context 773 of 20958
# Processing context 774 of 20958
# Processing context 775 of 20958
# Processing context 776 of 20958
# Processing context 777 of 20958
# Processing context 778 of 20958
# Processing context 779 of 20958
# Processing context 780 of 20958
# Processing context 781 of 20958
# Processing context 782 of 20958
# Processing context 783 of 20958
# Processing context 784 of 20958
# Processing context 785 of 20958
# Processing context 786 of 20958
# Processing context 787 of 20958
# Processing context 788 of 20958
# Processing context 789 of 20958
# Processing context 790 of 20958
# Processing context 791 of 20958
# Processing context 792 of 20958
# Processing context 793 of 20958
# Processing context 794 of 20958
# Processing context 795 of 20958
# Processing context 796 of 20958
# Processing context 797 of 20958
# Processing context 798 of 20958
# Processing context 799 of 20958
# Processing context 800 of 20958
# Processing context 801 of 20958
# Processing context 802 of 20958
# Processing context 803 of 20958
# Processing context 804 of 20958
# Processing context 805 of 20958
# Processing context 806 of 20958
# Processing context 807 of 20958
# Processing context 808 of 20958
# Processing context 809 of 20958
# Processing context 810 of 20958
# Processing context 811 of 20958
# Processing context 812 of 20958
# Processing context 813 of 20958
# Processing context 814 of 20958
# Processing context 815 of 20958
# Processing context 816 of 20958
# Processing context 817 of 20958
# Processing context 818 of 20958
# Processing context 819 of 20958
# Processing context 820 of 20958
# Processing context 821 of 20958
# Processing context 822 of 20958
# Processing context 823 of 20958
# Processing context 824 of 20958
# Processing context 825 of 20958
# Processing context 826 of 20958
# Processing context 827 of 20958
# Processing context 828 of 20958
# Processing context 829 of 20958
# Processing context 830 of 20958
# Processing context 831 of 20958
# Processing context 832 of 20958
# Processing context 833 of 20958
# Processing context 834 of 20958
# Processing context 835 of 20958
# Processing context 836 of 20958
# Processing context 837 of 20958
# Processing context 838 of 20958
# Processing context 839 of 20958
# Processing context 840 of 20958
# Processing context 841 of 20958
# Processing context 842 of 20958
# Processing context 843 of 20958
# Processing context 844 of 20958
# Processing context 845 of 20958
# Processing context 846 of 20958
# Processing context 847 of 20958
# Processing context 848 of 20958
# Processing context 849 of 20958
# Processing context 850 of 20958
# Processing context 851 of 20958
# Processing context 852 of 20958
# Processing context 853 of 20958
# Processing context 854 of 20958
# Processing context 855 of 20958
# Processing context 856 of 20958
# Processing context 857 of 20958
# Processing context 858 of 20958
# Processing context 859 of 20958
# Processing context 860 of 20958
# Processing context 861 of 20958
# Processing context 862 of 20958
# Processing context 863 of 20958
# Processing context 864 of 20958
# Processing context 865 of 20958
# Processing context 866 of 20958
# Processing context 867 of 20958
# Processing context 868 of 20958
# Processing context 869 of 20958
# Processing context 870 of 20958
# Processing context 871 of 20958
# Processing context 872 of 20958
# Processing context 873 of 20958
# Processing context 874 of 20958
# Processing context 875 of 20958
# Processing context 876 of 20958
# Processing context 877 of 20958
# Processing context 878 of 20958
# Processing context 879 of 20958
# Processing context 880 of 20958
# Processing context 881 of 20958
# Processing context 882 of 20958
# Processing context 883 of 20958
# Processing context 884 of 20958
# Processing context 885 of 20958
# Processing context 886 of 20958
# Processing context 887 of 20958
# Processing context 888 of 20958
# Processing context 889 of 20958
# Processing context 890 of 20958
# Processing context 891 of 20958
# Processing context 892 of 20958
# Processing context 893 of 20958
# Processing context 894 of 20958
# Processing context 895 of 20958
# Processing context 896 of 20958
# Processing context 897 of 20958
# Processing context 898 of 20958
# Processing context 899 of 20958
# Processing context 900 of 20958
# Processing context 901 of 20958
# Processing context 902 of 20958
# Processing context 903 of 20958
# Processing context 904 of 20958
# Processing context 905 of 20958
# Processing context 906 of 20958
# Processing context 907 of 20958
# Processing context 908 of 20958
# Processing context 909 of 20958
# Processing context 910 of 20958
# Processing context 911 of 20958
# Processing context 912 of 20958
# Processing context 913 of 20958
# Processing context 914 of 20958
# Processing context 915 of 20958
# Processing context 916 of 20958
# Processing context 917 of 20958
# Processing context 918 of 20958
# Processing context 919 of 20958
# Processing context 920 of 20958
# Processing context 921 of 20958
# Processing context 922 of 20958
# Processing context 923 of 20958
# Processing context 924 of 20958
# Processing context 925 of 20958
# Processing context 926 of 20958
# Processing context 927 of 20958
# Processing context 928 of 20958
# Processing context 929 of 20958
# Processing context 930 of 20958
# Processing context 931 of 20958
# Processing context 932 of 20958
# Processing context 933 of 20958
# Processing context 934 of 20958
# Processing context 935 of 20958
# Processing context 936 of 20958
# Processing context 937 of 20958
# Processing context 938 of 20958
# Processing context 939 of 20958
# Processing context 940 of 20958
# Processing context 941 of 20958
# Processing context 942 of 20958
# Processing context 943 of 20958
# Processing context 944 of 20958
# Processing context 945 of 20958
# Processing context 946 of 20958
# Processing context 947 of 20958
# Processing context 948 of 20958
# Processing context 949 of 20958
# Processing context 950 of 20958
# Processing context 951 of 20958
# Processing context 952 of 20958
# Processing context 953 of 20958
# Processing context 954 of 20958
# Processing context 955 of 20958
# Processing context 956 of 20958
# Processing context 957 of 20958
# Processing context 958 of 20958
# Processing context 959 of 20958
# Processing context 960 of 20958
# Processing context 961 of 20958
# Processing context 962 of 20958
# Processing context 963 of 20958
# Processing context 964 of 20958
# Processing context 965 of 20958
# Processing context 966 of 20958
# Processing context 967 of 20958
# Processing context 968 of 20958
# Processing context 969 of 20958
# Processing context 970 of 20958
# Processing context 971 of 20958
# Processing context 972 of 20958
# Processing context 973 of 20958
# Processing context 974 of 20958
# Processing context 975 of 20958
# Processing context 976 of 20958
# Processing context 977 of 20958
# Processing context 978 of 20958
# Processing context 979 of 20958
# Processing context 980 of 20958
# Processing context 981 of 20958
# Processing context 982 of 20958
# Processing context 983 of 20958
# Processing context 984 of 20958
# Processing context 985 of 20958
# Processing context 986 of 20958
# Processing context 987 of 20958
# Processing context 988 of 20958
# Processing context 989 of 20958
# Processing context 990 of 20958
# Processing context 991 of 20958
# Processing context 992 of 20958
# Processing context 993 of 20958
# Processing context 994 of 20958
# Processing context 995 of 20958
# Processing context 996 of 20958
# Processing context 997 of 20958
# Processing context 998 of 20958
# Processing context 999 of 20958
# Processing context 1000 of 20958
# Processing context 1001 of 20958
# Processing context 1002 of 20958
# Processing context 1003 of 20958
# Processing context 1004 of 20958
# Processing context 1005 of 20958
# Processing context 1006 of 20958
# Processing context 1007 of 20958
# Processing context 1008 of 20958
# Processing context 1009 of 20958
# Processing context 1010 of 20958
# Processing context 1011 of 20958
# Processing context 1012 of 20958
# Processing context 1013 of 20958
# Processing context 1014 of 20958
# Processing context 1015 of 20958
# Processing context 1016 of 20958
# Processing context 1017 of 20958
# Processing context 1018 of 20958
# Processing context 1019 of 20958
# Processing context 1020 of 20958
# Processing context 1021 of 20958
# Processing context 1022 of 20958
# Processing context 1023 of 20958
# Processing context 1024 of 20958
# Processing context 1025 of 20958
# Processing context 1026 of 20958
# Processing context 1027 of 20958
# Processing context 1028 of 20958
# Processing context 1029 of 20958
# Processing context 1030 of 20958
# Processing context 1031 of 20958
# Processing context 1032 of 20958
# Processing context 1033 of 20958
# Processing context 1034 of 20958
# Processing context 1035 of 20958
# Processing context 1036 of 20958
# Processing context 1037 of 20958
# Processing context 1038 of 20958
# Processing context 1039 of 20958
# Processing context 1040 of 20958
# Processing context 1041 of 20958
# Processing context 1042 of 20958
# Processing context 1043 of 20958
# Processing context 1044 of 20958
# Processing context 1045 of 20958
# Processing context 1046 of 20958
# Processing context 1047 of 20958
# Processing context 1048 of 20958
# Processing context 1049 of 20958
# Processing context 1050 of 20958
# Processing context 1051 of 20958
# Processing context 1052 of 20958
# Processing context 1053 of 20958
# Processing context 1054 of 20958
# Processing context 1055 of 20958
# Processing context 1056 of 20958
# Processing context 1057 of 20958
# Processing context 1058 of 20958
# Processing context 1059 of 20958
# Processing context 1060 of 20958
# Processing context 1061 of 20958
# Processing context 1062 of 20958
# Processing context 1063 of 20958
# Processing context 1064 of 20958
# Processing context 1065 of 20958
# Processing context 1066 of 20958
# Processing context 1067 of 20958
# Processing context 1068 of 20958
# Processing context 1069 of 20958
# Processing context 1070 of 20958
# Processing context 1071 of 20958
# Processing context 1072 of 20958
# Processing context 1073 of 20958
# Processing context 1074 of 20958
# Processing context 1075 of 20958
# Processing context 1076 of 20958
# Processing context 1077 of 20958
# Processing context 1078 of 20958
# Processing context 1079 of 20958
# Processing context 1080 of 20958
# Processing context 1081 of 20958
# Processing context 1082 of 20958
# Processing context 1083 of 20958
# Processing context 1084 of 20958
# Processing context 1085 of 20958
# Processing context 1086 of 20958
# Processing context 1087 of 20958
# Processing context 1088 of 20958
# Processing context 1089 of 20958
# Processing context 1090 of 20958
# Processing context 1091 of 20958
# Processing context 1092 of 20958
# Processing context 1093 of 20958
# Processing context 1094 of 20958
# Processing context 1095 of 20958
# Processing context 1096 of 20958
# Processing context 1097 of 20958
# Processing context 1098 of 20958
# Processing context 1099 of 20958
# Processing context 1100 of 20958
# Processing context 1101 of 20958
# Processing context 1102 of 20958
# Processing context 1103 of 20958
# Processing context 1104 of 20958
# Processing context 1105 of 20958
# Processing context 1106 of 20958
# Processing context 1107 of 20958
# Processing context 1108 of 20958
# Processing context 1109 of 20958
# Processing context 1110 of 20958
# Processing context 1111 of 20958
# Processing context 1112 of 20958
# Processing context 1113 of 20958
# Processing context 1114 of 20958
# Processing context 1115 of 20958
# Processing context 1116 of 20958
# Processing context 1117 of 20958
# Processing context 1118 of 20958
# Processing context 1119 of 20958
# Processing context 1120 of 20958
# Processing context 1121 of 20958
# Processing context 1122 of 20958
# Processing context 1123 of 20958
# Processing context 1124 of 20958
# Processing context 1125 of 20958
# Processing context 1126 of 20958
# Processing context 1127 of 20958
# Processing context 1128 of 20958
# Processing context 1129 of 20958
# Processing context 1130 of 20958
# Processing context 1131 of 20958
# Processing context 1132 of 20958
# Processing context 1133 of 20958
# Processing context 1134 of 20958
# Processing context 1135 of 20958
# Processing context 1136 of 20958
# Processing context 1137 of 20958
# Processing context 1138 of 20958
# Processing context 1139 of 20958
# Processing context 1140 of 20958
# Processing context 1141 of 20958
# Processing context 1142 of 20958
# Processing context 1143 of 20958
# Processing context 1144 of 20958
# Processing context 1145 of 20958
# Processing context 1146 of 20958
# Processing context 1147 of 20958
# Processing context 1148 of 20958
# Processing context 1149 of 20958
# Processing context 1150 of 20958
# Processing context 1151 of 20958
# Processing context 1152 of 20958
# Processing context 1153 of 20958
# Processing context 1154 of 20958
# Processing context 1155 of 20958
# Processing context 1156 of 20958
# Processing context 1157 of 20958
# Processing context 1158 of 20958
# Processing context 1159 of 20958
# Processing context 1160 of 20958
# Processing context 1161 of 20958
# Processing context 1162 of 20958
# Processing context 1163 of 20958
# Processing context 1164 of 20958
# Processing context 1165 of 20958
# Processing context 1166 of 20958
# Processing context 1167 of 20958
# Processing context 1168 of 20958
# Processing context 1169 of 20958
# Processing context 1170 of 20958
# Processing context 1171 of 20958
# Processing context 1172 of 20958
# Processing context 1173 of 20958
# Processing context 1174 of 20958
# Processing context 1175 of 20958
# Processing context 1176 of 20958
# Processing context 1177 of 20958
# Processing context 1178 of 20958
# Processing context 1179 of 20958
# Processing context 1180 of 20958
# Processing context 1181 of 20958
# Processing context 1182 of 20958
# Processing context 1183 of 20958
# Processing context 1184 of 20958
# Processing context 1185 of 20958
# Processing context 1186 of 20958
# Processing context 1187 of 20958
# Processing context 1188 of 20958
# Processing context 1189 of 20958
# Processing context 1190 of 20958
# Processing context 1191 of 20958
# Processing context 1192 of 20958
# Processing context 1193 of 20958
# Processing context 1194 of 20958
# Processing context 1195 of 20958
# Processing context 1196 of 20958
# Processing context 1197 of 20958
# Processing context 1198 of 20958
# Processing context 1199 of 20958
# Processing context 1200 of 20958
# Processing context 1201 of 20958
# Processing context 1202 of 20958
# Processing context 1203 of 20958
# Processing context 1204 of 20958
# Processing context 1205 of 20958
# Processing context 1206 of 20958
# Processing context 1207 of 20958
# Processing context 1208 of 20958
# Processing context 1209 of 20958
# Processing context 1210 of 20958
# Processing context 1211 of 20958
# Processing context 1212 of 20958
# Processing context 1213 of 20958
# Processing context 1214 of 20958
# Processing context 1215 of 20958
# Processing context 1216 of 20958
# Processing context 1217 of 20958
# Processing context 1218 of 20958
# Processing context 1219 of 20958
# Processing context 1220 of 20958
# Processing context 1221 of 20958
# Processing context 1222 of 20958
# Processing context 1223 of 20958
# Processing context 1224 of 20958
# Processing context 1225 of 20958
# Processing context 1226 of 20958
# Processing context 1227 of 20958
# Processing context 1228 of 20958
# Processing context 1229 of 20958
# Processing context 1230 of 20958
# Processing context 1231 of 20958
# Processing context 1232 of 20958
# Processing context 1233 of 20958
# Processing context 1234 of 20958
# Processing context 1235 of 20958
# Processing context 1236 of 20958
# Processing context 1237 of 20958
# Processing context 1238 of 20958
# Processing context 1239 of 20958
# Processing context 1240 of 20958
# Processing context 1241 of 20958
# Processing context 1242 of 20958
# Processing context 1243 of 20958
# Processing context 1244 of 20958
# Processing context 1245 of 20958
# Processing context 1246 of 20958
# Processing context 1247 of 20958
# Processing context 1248 of 20958
# Processing context 1249 of 20958
# Processing context 1250 of 20958
# Processing context 1251 of 20958
# Processing context 1252 of 20958
# Processing context 1253 of 20958
# Processing context 1254 of 20958
# Processing context 1255 of 20958
# Processing context 1256 of 20958
# Processing context 1257 of 20958
# Processing context 1258 of 20958
# Processing context 1259 of 20958
# Processing context 1260 of 20958
# Processing context 1261 of 20958
# Processing context 1262 of 20958
# Processing context 1263 of 20958
# Processing context 1264 of 20958
# Processing context 1265 of 20958
# Processing context 1266 of 20958
# Processing context 1267 of 20958
# Processing context 1268 of 20958
# Processing context 1269 of 20958
# Processing context 1270 of 20958
# Processing context 1271 of 20958
# Processing context 1272 of 20958
# Processing context 1273 of 20958
# Processing context 1274 of 20958
# Processing context 1275 of 20958
# Processing context 1276 of 20958
# Processing context 1277 of 20958
# Processing context 1278 of 20958
# Processing context 1279 of 20958
# Processing context 1280 of 20958
# Processing context 1281 of 20958
# Processing context 1282 of 20958
# Processing context 1283 of 20958
# Processing context 1284 of 20958
# Processing context 1285 of 20958
# Processing context 1286 of 20958
# Processing context 1287 of 20958
# Processing context 1288 of 20958
# Processing context 1289 of 20958
# Processing context 1290 of 20958
# Processing context 1291 of 20958
# Processing context 1292 of 20958
# Processing context 1293 of 20958
# Processing context 1294 of 20958
# Processing context 1295 of 20958
# Processing context 1296 of 20958
# Processing context 1297 of 20958
# Processing context 1298 of 20958
# Processing context 1299 of 20958
# Processing context 1300 of 20958
# Processing context 1301 of 20958
# Processing context 1302 of 20958
# Processing context 1303 of 20958
# Processing context 1304 of 20958
# Processing context 1305 of 20958
# Processing context 1306 of 20958
# Processing context 1307 of 20958
# Processing context 1308 of 20958
# Processing context 1309 of 20958
# Processing context 1310 of 20958
# Processing context 1311 of 20958
# Processing context 1312 of 20958
# Processing context 1313 of 20958
# Processing context 1314 of 20958
# Processing context 1315 of 20958
# Processing context 1316 of 20958
# Processing context 1317 of 20958
# Processing context 1318 of 20958
# Processing context 1319 of 20958
# Processing context 1320 of 20958
# Processing context 1321 of 20958
# Processing context 1322 of 20958
# Processing context 1323 of 20958
# Processing context 1324 of 20958
# Processing context 1325 of 20958
# Processing context 1326 of 20958
# Processing context 1327 of 20958
# Processing context 1328 of 20958
# Processing context 1329 of 20958
# Processing context 1330 of 20958
# Processing context 1331 of 20958
# Processing context 1332 of 20958
# Processing context 1333 of 20958
# Processing context 1334 of 20958
# Processing context 1335 of 20958
# Processing context 1336 of 20958
# Processing context 1337 of 20958
# Processing context 1338 of 20958
# Processing context 1339 of 20958
# Processing context 1340 of 20958
# Processing context 1341 of 20958
# Processing context 1342 of 20958
# Processing context 1343 of 20958
# Processing context 1344 of 20958
# Processing context 1345 of 20958
# Processing context 1346 of 20958
# Processing context 1347 of 20958
# Processing context 1348 of 20958
# Processing context 1349 of 20958
# Processing context 1350 of 20958
# Processing context 1351 of 20958
# Processing context 1352 of 20958
# Processing context 1353 of 20958
# Processing context 1354 of 20958
# Processing context 1355 of 20958
# Processing context 1356 of 20958
# Processing context 1357 of 20958
# Processing context 1358 of 20958
# Processing context 1359 of 20958
# Processing context 1360 of 20958
# Processing context 1361 of 20958
# Processing context 1362 of 20958
# Processing context 1363 of 20958
# Processing context 1364 of 20958
# Processing context 1365 of 20958
# Processing context 1366 of 20958
# Processing context 1367 of 20958
# Processing context 1368 of 20958
# Processing context 1369 of 20958
# Processing context 1370 of 20958
# Processing context 1371 of 20958
# Processing context 1372 of 20958
# Processing context 1373 of 20958
# Processing context 1374 of 20958
# Processing context 1375 of 20958
# Processing context 1376 of 20958
# Processing context 1377 of 20958
# Processing context 1378 of 20958
# Processing context 1379 of 20958
# Processing context 1380 of 20958
# Processing context 1381 of 20958
# Processing context 1382 of 20958
# Processing context 1383 of 20958
# Processing context 1384 of 20958
# Processing context 1385 of 20958
# Processing context 1386 of 20958
# Processing context 1387 of 20958
# Processing context 1388 of 20958
# Processing context 1389 of 20958
# Processing context 1390 of 20958
# Processing context 1391 of 20958
# Processing context 1392 of 20958
# Processing context 1393 of 20958
# Processing context 1394 of 20958
# Processing context 1395 of 20958
# Processing context 1396 of 20958
# Processing context 1397 of 20958
# Processing context 1398 of 20958
# Processing context 1399 of 20958
# Processing context 1400 of 20958
# Processing context 1401 of 20958
# Processing context 1402 of 20958
# Processing context 1403 of 20958
# Processing context 1404 of 20958
# Processing context 1405 of 20958
# Processing context 1406 of 20958
# Processing context 1407 of 20958
# Processing context 1408 of 20958
# Processing context 1409 of 20958
# Processing context 1410 of 20958
# Processing context 1411 of 20958
# Processing context 1412 of 20958
# Processing context 1413 of 20958
# Processing context 1414 of 20958
# Processing context 1415 of 20958
# Processing context 1416 of 20958
# Processing context 1417 of 20958
# Processing context 1418 of 20958
# Processing context 1419 of 20958
# Processing context 1420 of 20958
# Processing context 1421 of 20958
# Processing context 1422 of 20958
# Processing context 1423 of 20958
# Processing context 1424 of 20958
# Processing context 1425 of 20958
# Processing context 1426 of 20958
# Processing context 1427 of 20958
# Processing context 1428 of 20958
# Processing context 1429 of 20958
# Processing context 1430 of 20958
# Processing context 1431 of 20958
# Processing context 1432 of 20958
# Processing context 1433 of 20958
# Processing context 1434 of 20958
# Processing context 1435 of 20958
# Processing context 1436 of 20958
# Processing context 1437 of 20958
# Processing context 1438 of 20958
# Processing context 1439 of 20958
# Processing context 1440 of 20958
# Processing context 1441 of 20958
# Processing context 1442 of 20958
# Processing context 1443 of 20958
# Processing context 1444 of 20958
# Processing context 1445 of 20958
# Processing context 1446 of 20958
# Processing context 1447 of 20958
# Processing context 1448 of 20958
# Processing context 1449 of 20958
# Processing context 1450 of 20958
# Processing context 1451 of 20958
# Processing context 1452 of 20958
# Processing context 1453 of 20958
# Processing context 1454 of 20958
# Processing context 1455 of 20958
# Processing context 1456 of 20958
# Processing context 1457 of 20958
# Processing context 1458 of 20958
# Processing context 1459 of 20958
# Processing context 1460 of 20958
# Processing context 1461 of 20958
# Processing context 1462 of 20958
# Processing context 1463 of 20958
# Processing context 1464 of 20958
# Processing context 1465 of 20958
# Processing context 1466 of 20958
# Processing context 1467 of 20958
# Processing context 1468 of 20958
# Processing context 1469 of 20958
# Processing context 1470 of 20958
# Processing context 1471 of 20958
# Processing context 1472 of 20958
# Processing context 1473 of 20958
# Processing context 1474 of 20958
# Processing context 1475 of 20958
# Processing context 1476 of 20958
# Processing context 1477 of 20958
# Processing context 1478 of 20958
# Processing context 1479 of 20958
# Processing context 1480 of 20958
# Processing context 1481 of 20958
# Processing context 1482 of 20958
# Processing context 1483 of 20958
# Processing context 1484 of 20958
# Processing context 1485 of 20958
# Processing context 1486 of 20958
# Processing context 1487 of 20958
# Processing context 1488 of 20958
# ...
# Processing context 20490 of 20958
# Processing context 20491 of 20958
# Processing context 20492 of 20958
# Processing context 20493 of 20958
# Processing context 20494 of 20958
# Processing context 20495 of 20958
# Processing context 20496 of 20958
# Processing context 20497 of 20958
# Processing context 20498 of 20958
# Processing context 20499 of 20958
# Processing context 20500 of 20958
# Processing context 20501 of 20958
# Processing context 20502 of 20958
# Processing context 20503 of 20958
# Processing context 20504 of 20958
# Processing context 20505 of 20958
# Processing context 20506 of 20958
# Processing context 20507 of 20958
# Processing context 20508 of 20958
# Processing context 20509 of 20958
# Processing context 20510 of 20958
# Processing context 20511 of 20958
# Processing context 20512 of 20958
# Processing context 20513 of 20958
# Processing context 20514 of 20958
# Processing context 20515 of 20958
# Processing context 20516 of 20958
# Processing context 20517 of 20958
# Processing context 20518 of 20958
# Processing context 20519 of 20958
# Processing context 20520 of 20958
# Processing context 20521 of 20958
# Processing context 20522 of 20958
# Processing context 20523 of 20958
# Processing context 20524 of 20958
# Processing context 20525 of 20958
# Processing context 20526 of 20958
# Processing context 20527 of 20958
# Processing context 20528 of 20958
# Processing context 20529 of 20958
# Processing context 20530 of 20958
# Processing context 20531 of 20958
# Processing context 20532 of 20958
# Processing context 20533 of 20958
# Processing context 20534 of 20958
# Processing context 20535 of 20958
# Processing context 20536 of 20958
# Processing context 20537 of 20958
# Processing context 20538 of 20958
# Processing context 20539 of 20958
# Processing context 20540 of 20958
# Processing context 20541 of 20958
# Processing context 20542 of 20958
# Processing context 20543 of 20958
# Processing context 20544 of 20958
# Processing context 20545 of 20958
# Processing context 20546 of 20958
# Processing context 20547 of 20958
# Processing context 20548 of 20958
# Processing context 20549 of 20958
# Processing context 20550 of 20958
# Processing context 20551 of 20958
# Processing context 20552 of 20958
# Processing context 20553 of 20958
# Processing context 20554 of 20958
# Processing context 20555 of 20958
# Processing context 20556 of 20958
# Processing context 20557 of 20958
# Processing context 20558 of 20958
# Processing context 20559 of 20958
# Processing context 20560 of 20958
# Processing context 20561 of 20958
# Processing context 20562 of 20958
# Processing context 20563 of 20958
# Processing context 20564 of 20958
# Processing context 20565 of 20958
# Processing context 20566 of 20958
# Processing context 20567 of 20958
# Processing context 20568 of 20958
# Processing context 20569 of 20958
# Processing context 20570 of 20958
# Processing context 20571 of 20958
# Processing context 20572 of 20958
# Processing context 20573 of 20958
# Processing context 20574 of 20958
# Processing context 20575 of 20958
# Processing context 20576 of 20958
# Processing context 20577 of 20958
# Processing context 20578 of 20958
# Processing context 20579 of 20958
# Processing context 20580 of 20958
# Processing context 20581 of 20958
# Processing context 20582 of 20958
# Processing context 20583 of 20958
# Processing context 20584 of 20958
# Processing context 20585 of 20958
# Processing context 20586 of 20958
# Processing context 20587 of 20958
# Processing context 20588 of 20958
# Processing context 20589 of 20958
# Processing context 20590 of 20958
# Processing context 20591 of 20958
# Processing context 20592 of 20958
# Processing context 20593 of 20958
# Processing context 20594 of 20958
# Processing context 20595 of 20958
# Processing context 20596 of 20958
# Processing context 20597 of 20958
# Processing context 20598 of 20958
# Processing context 20599 of 20958
# Processing context 20600 of 20958
# Processing context 20601 of 20958
# Processing context 20602 of 20958
# Processing context 20603 of 20958
# Processing context 20604 of 20958
# Processing context 20605 of 20958
# Processing context 20606 of 20958
# Processing context 20607 of 20958
# Processing context 20608 of 20958
# Processing context 20609 of 20958
# Processing context 20610 of 20958
# Processing context 20611 of 20958
# Processing context 20612 of 20958
# Processing context 20613 of 20958
# Processing context 20614 of 20958
# Processing context 20615 of 20958
# Processing context 20616 of 20958
# Processing context 20617 of 20958
# Processing context 20618 of 20958
# Processing context 20619 of 20958
# Processing context 20620 of 20958
# Processing context 20621 of 20958
# Processing context 20622 of 20958
# Processing context 20623 of 20958
# Processing context 20624 of 20958
# Processing context 20625 of 20958
# Processing context 20626 of 20958
# Processing context 20627 of 20958
# Processing context 20628 of 20958
# Processing context 20629 of 20958
# Processing context 20630 of 20958
# Processing context 20631 of 20958
# Processing context 20632 of 20958
# Processing context 20633 of 20958
# Processing context 20634 of 20958
# Processing context 20635 of 20958
# Processing context 20636 of 20958
# Processing context 20637 of 20958
# Processing context 20638 of 20958
# Processing context 20639 of 20958
# Processing context 20640 of 20958
# Processing context 20641 of 20958
# Processing context 20642 of 20958
# Processing context 20643 of 20958
# Processing context 20644 of 20958
# Processing context 20645 of 20958
# Processing context 20646 of 20958
# Processing context 20647 of 20958
# Processing context 20648 of 20958
# Processing context 20649 of 20958
# Processing context 20650 of 20958
# Processing context 20651 of 20958
# Processing context 20652 of 20958
# Processing context 20653 of 20958
# Processing context 20654 of 20958
# Processing context 20655 of 20958
# Processing context 20656 of 20958
# Processing context 20657 of 20958
# Processing context 20658 of 20958
# Processing context 20659 of 20958
# Processing context 20660 of 20958
# Processing context 20661 of 20958
# Processing context 20662 of 20958
# Processing context 20663 of 20958
# Processing context 20664 of 20958
# Processing context 20665 of 20958
# Processing context 20666 of 20958
# Processing context 20667 of 20958
# Processing context 20668 of 20958
# Processing context 20669 of 20958
# Processing context 20670 of 20958
# Processing context 20671 of 20958
# Processing context 20672 of 20958
# Processing context 20673 of 20958
# Processing context 20674 of 20958
# Processing context 20675 of 20958
# Processing context 20676 of 20958
# Processing context 20677 of 20958
# Processing context 20678 of 20958
# Processing context 20679 of 20958
# Processing context 20680 of 20958
# Processing context 20681 of 20958
# Processing context 20682 of 20958
# Processing context 20683 of 20958
# Processing context 20684 of 20958
# Processing context 20685 of 20958
# Processing context 20686 of 20958
# Processing context 20687 of 20958
# Processing context 20688 of 20958
# Processing context 20689 of 20958
# Processing context 20690 of 20958
# Processing context 20691 of 20958
# Processing context 20692 of 20958
# Processing context 20693 of 20958
# Processing context 20694 of 20958
# Processing context 20695 of 20958
# Processing context 20696 of 20958
# Processing context 20697 of 20958
# Processing context 20698 of 20958
# Processing context 20699 of 20958
# Processing context 20700 of 20958
# Processing context 20701 of 20958
# Processing context 20702 of 20958
# Processing context 20703 of 20958
# Processing context 20704 of 20958
# Processing context 20705 of 20958
# Processing context 20706 of 20958
# Processing context 20707 of 20958
# Processing context 20708 of 20958
# Processing context 20709 of 20958
# Processing context 20710 of 20958
# Processing context 20711 of 20958
# Processing context 20712 of 20958
# Processing context 20713 of 20958
# Processing context 20714 of 20958
# Processing context 20715 of 20958
# Processing context 20716 of 20958
# Processing context 20717 of 20958
# Processing context 20718 of 20958
# Processing context 20719 of 20958
# Processing context 20720 of 20958
# Processing context 20721 of 20958
# Processing context 20722 of 20958
# Processing context 20723 of 20958
# Processing context 20724 of 20958
# Processing context 20725 of 20958
# Processing context 20726 of 20958
# Processing context 20727 of 20958
# Processing context 20728 of 20958
# Processing context 20729 of 20958
# Processing context 20730 of 20958
# Processing context 20731 of 20958
# Processing context 20732 of 20958
# Processing context 20733 of 20958
# Processing context 20734 of 20958
# Processing context 20735 of 20958
# Processing context 20736 of 20958
# Processing context 20737 of 20958
# Processing context 20738 of 20958
# Processing context 20739 of 20958
# Processing context 20740 of 20958
# Processing context 20741 of 20958
# Processing context 20742 of 20958
# Processing context 20743 of 20958
# Processing context 20744 of 20958
# Processing context 20745 of 20958
# Processing context 20746 of 20958
# Processing context 20747 of 20958
# Processing context 20748 of 20958
# Processing context 20749 of 20958
# Processing context 20750 of 20958
# Processing context 20751 of 20958
# Processing context 20752 of 20958
# Processing context 20753 of 20958
# Processing context 20754 of 20958
# Processing context 20755 of 20958
# Processing context 20756 of 20958
# Processing context 20757 of 20958
# Processing context 20758 of 20958
# Processing context 20759 of 20958
# Processing context 20760 of 20958
# Processing context 20761 of 20958
# Processing context 20762 of 20958
# Processing context 20763 of 20958
# Processing context 20764 of 20958
# Processing context 20765 of 20958
# Processing context 20766 of 20958
# Processing context 20767 of 20958
# Processing context 20768 of 20958
# Processing context 20769 of 20958
# Processing context 20770 of 20958
# Processing context 20771 of 20958
# Processing context 20772 of 20958
# Processing context 20773 of 20958
# Processing context 20774 of 20958
# Processing context 20775 of 20958
# Processing context 20776 of 20958
# Processing context 20777 of 20958
# Processing context 20778 of 20958
# Processing context 20779 of 20958
# Processing context 20780 of 20958
# Processing context 20781 of 20958
# Processing context 20782 of 20958
# Processing context 20783 of 20958
# Processing context 20784 of 20958
# Processing context 20785 of 20958
# Processing context 20786 of 20958
# Processing context 20787 of 20958
# Processing context 20788 of 20958
# Processing context 20789 of 20958
# Processing context 20790 of 20958
# Processing context 20791 of 20958
# Processing context 20792 of 20958
# Processing context 20793 of 20958
# Processing context 20794 of 20958
# Processing context 20795 of 20958
# Processing context 20796 of 20958
# Processing context 20797 of 20958
# Processing context 20798 of 20958
# Processing context 20799 of 20958
# Processing context 20800 of 20958
# Processing context 20801 of 20958
# Processing context 20802 of 20958
# Processing context 20803 of 20958
# Processing context 20804 of 20958
# Processing context 20805 of 20958
# Processing context 20806 of 20958
# Processing context 20807 of 20958
# Processing context 20808 of 20958
# Processing context 20809 of 20958
# Processing context 20810 of 20958
# Processing context 20811 of 20958
# Processing context 20812 of 20958
# Processing context 20813 of 20958
# Processing context 20814 of 20958
# Processing context 20815 of 20958
# Processing context 20816 of 20958
# Processing context 20817 of 20958
# Processing context 20818 of 20958
# Processing context 20819 of 20958
# Processing context 20820 of 20958
# Processing context 20821 of 20958
# Processing context 20822 of 20958
# Processing context 20823 of 20958
# Processing context 20824 of 20958
# Processing context 20825 of 20958
# Processing context 20826 of 20958
# Processing context 20827 of 20958
# Processing context 20828 of 20958
# Processing context 20829 of 20958
# Processing context 20830 of 20958
# Processing context 20831 of 20958
# Processing context 20832 of 20958
# Processing context 20833 of 20958
# Processing context 20834 of 20958
# Processing context 20835 of 20958
# Processing context 20836 of 20958
# Processing context 20837 of 20958
# Processing context 20838 of 20958
# Processing context 20839 of 20958
# Processing context 20840 of 20958
# Processing context 20841 of 20958
# Processing context 20842 of 20958
# Processing context 20843 of 20958
# Processing context 20844 of 20958
# Processing context 20845 of 20958
# Processing context 20846 of 20958
# Processing context 20847 of 20958
# Processing context 20848 of 20958
# Processing context 20849 of 20958
# Processing context 20850 of 20958
# Processing context 20851 of 20958
# Processing context 20852 of 20958
# Processing context 20853 of 20958
# Processing context 20854 of 20958
# Processing context 20855 of 20958
# Processing context 20856 of 20958
# Processing context 20857 of 20958
# Processing context 20858 of 20958
# Processing context 20859 of 20958
# Processing context 20860 of 20958
# Processing context 20861 of 20958
# Processing context 20862 of 20958
# Processing context 20863 of 20958
# Processing context 20864 of 20958
# Processing context 20865 of 20958
# Processing context 20866 of 20958
# Processing context 20867 of 20958
# Processing context 20868 of 20958
# Processing context 20869 of 20958
# Processing context 20870 of 20958
# Processing context 20871 of 20958
# Processing context 20872 of 20958
# Processing context 20873 of 20958
# Processing context 20874 of 20958
# Processing context 20875 of 20958
# Processing context 20876 of 20958
# Processing context 20877 of 20958
# Processing context 20878 of 20958
# Processing context 20879 of 20958
# Processing context 20880 of 20958
# Processing context 20881 of 20958
# Processing context 20882 of 20958
# Processing context 20883 of 20958
# Processing context 20884 of 20958
# Processing context 20885 of 20958
# Processing context 20886 of 20958
# Processing context 20887 of 20958
# Processing context 20888 of 20958
# Processing context 20889 of 20958
# Processing context 20890 of 20958
# Processing context 20891 of 20958
# Processing context 20892 of 20958
# Processing context 20893 of 20958
# Processing context 20894 of 20958
# Processing context 20895 of 20958
# Processing context 20896 of 20958
# Processing context 20897 of 20958
# Processing context 20898 of 20958
# Processing context 20899 of 20958
# Processing context 20900 of 20958
# Processing context 20901 of 20958
# Processing context 20902 of 20958
# Processing context 20903 of 20958
# Processing context 20904 of 20958
# Processing context 20905 of 20958
# Processing context 20906 of 20958
# Processing context 20907 of 20958
# Processing context 20908 of 20958
# Processing context 20909 of 20958
# Processing context 20910 of 20958
# Processing context 20911 of 20958
# Processing context 20912 of 20958
# Processing context 20913 of 20958
# Processing context 20914 of 20958
# Processing context 20915 of 20958
# Processing context 20916 of 20958
# Processing context 20917 of 20958
# Processing context 20918 of 20958
# Processing context 20919 of 20958
# Processing context 20920 of 20958
# Processing context 20921 of 20958
# Processing context 20922 of 20958
# Processing context 20923 of 20958
# Processing context 20924 of 20958
# Processing context 20925 of 20958
# Processing context 20926 of 20958
# Processing context 20927 of 20958
# Processing context 20928 of 20958
# Processing context 20929 of 20958
# Processing context 20930 of 20958
# Processing context 20931 of 20958
# Processing context 20932 of 20958
# Processing context 20933 of 20958
# Processing context 20934 of 20958
# Processing context 20935 of 20958
# Processing context 20936 of 20958
# Processing context 20937 of 20958
# Processing context 20938 of 20958
# Processing context 20939 of 20958
# Processing context 20940 of 20958
# Processing context 20941 of 20958
# Processing context 20942 of 20958
# Processing context 20943 of 20958
# Processing context 20944 of 20958
# Processing context 20945 of 20958
# Processing context 20946 of 20958
# Processing context 20947 of 20958
# Processing context 20948 of 20958
# Processing context 20949 of 20958
# Processing context 20950 of 20958
# Processing context 20951 of 20958
# Processing context 20952 of 20958
# Processing context 20953 of 20958
# Processing context 20954 of 20958
# Processing context 20955 of 20958
# Processing context 20956 of 20958
# Processing context 20957 of 20958
# Processing context 20958 of 20958
# 52 chunks embedded successfully!
